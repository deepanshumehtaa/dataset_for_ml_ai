# %%
from tkinter import *
from PIL import Image,ImageTk
from tkinter import messagebox

import seaborn as sb
import matplotlib.pyplot as plt

import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
#df = pd.read_csv('https://raw.githubusercontent.com/deepanshumehtaa/csvfiles/master/diabetes_preprocess.csv')
sb.heatmap(df.isnull() )
plt.show()

# %%
df.columns
#df.drop(['Insulin', 'SkinThickness'], axis = 1, inplace = True)
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure   BMI  DiabetesPedigreeFunction  Age  \
# 0            6    148.0           72.0  33.6                     0.627    5
# 1            1     85.0           66.0  26.6                     0.351   31
# 2            8    183.0           64.0  23.3                     0.672   32
# 3            1     89.0           66.0  28.1                     0.167   21
# 4            0    137.0            4.0  43.1                     2.288   33
#
#    Outcome
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %%
df.fillna(df.median(), inplace =True)
df.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure   BMI  DiabetesPedigreeFunction  Age  \
# 0            6    148.0           72.0  33.6                     0.627    5
# 1            1     85.0           66.0  26.6                     0.351   31
# 2            8    183.0           64.0  23.3                     0.672   32
# 3            1     89.0           66.0  28.1                     0.167   21
# 4            0    137.0            4.0  43.1                     2.288   33
#
#    Outcome
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %%
X_train, X_test, y_train, y_test = train_test_split(df.drop('Outcome',axis=1),df['Outcome'], test_size=0.30,random_state=101)
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score

kfold=KFold(n_splits=10,random_state=10)
logKFold=LogisticRegression()
logKFold.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)

# %%
def action1():
        data=[[int(t2.get()),int(t3.get()),int(t4.get()) , 
              int(t5.get()),int(t6.get()),float(t7.get()), 
              float(t8.get()),int(t9.get())]] 
    
        prediction1=logKFold.predict(data)
        if( prediction1==1): 
            messagebox.showinfo("Result","You Have Diabetes(u should get check it from the lab as our accuracy is only 76%)") 
        else:
             messagebox.showinfo("Result","You Do Not Have Diabetes (tip:eat less,eat good)")

# %%
def action2():
        data=[[int(t2.get()),int(t3.get()),int(t4.get()) , 
              int(t5.get()),int(t6.get()),float(t7.get()), 
              float(t8.get()),int(t9.get())]] 
        
        prediction=logmodel.predict(data)
        if( prediction==1): 
            messagebox.showinfo("Result","You Have Diabetes(u should get check it from the lab as our accuracy is only 78%)") 
        else:
             messagebox.showinfo("Result","You Do Not Have Diabetes (tip:eat less,eat good)")

# %%
root=Tk()
root.geometry('1100x734+0+0')
root.config(background="light yellow")
l1=Label(root,text="Welcome to Diabetes Checking")
l1.pack(fill="both",expand="True")


#image=ImageTk.PhotoImage(Image.open('C:\\Users\\g\\Desktop\\assingment od CDAC\\diabtes2.jpg'))
image=ImageTk.PhotoImage(Image.open(r'C:\Users\Administrator\Desktop\C-DAC\HC.png'))
#'C:\Users\Administrator\Desktop\C-DAC'
mylabel = Label(image=image)
mylabel.pack()


l0=Label(root,text='Diabetes CheckUp')
l0.place(relx=0.45,rely=0.2)

b2=Button(root,text='check diabetes (without k fold)',command=action2)
b2.place(relx=0.35,rely=0.65)

b1=Button(root,text='check diabetes (with k fold)',command=action1)
b1.place(relx=0.55,rely=0.65)

l2=Label(root,text='Pregnancies')
l3=Label(root,text='Glucose')
l4=Label(root,text='Blood Pressure')
l5=Label(root,text='Skin Thickness')
l6=Label(root,text='Insulin')
l7=Label(root,text='BMI')
l8=Label(root,text='Diabetes Pedigree Function')
l9=Label(root,text='Age')
t2=Entry(root,width=30)
t3=Entry(root,width=30)
t4=Entry(root,width=30)
t5=Entry(root,width=30)
t6=Entry(root,width=30)
t7=Entry(root,width=30)
t8=Entry(root,width=30)
t9=Entry(root,width=30)
l2.place(relx=0.35,rely=0.25)
l3.place(relx=0.35,rely=0.3)
l4.place(relx=0.35,rely=0.35)
l5.place(relx=0.35,rely=0.4)
l6.place(relx=0.35,rely=0.45)
l7.place(relx=0.35,rely=0.5)
l8.place(relx=0.35,rely=0.55)
l9.place(relx=0.35,rely=0.6)
t2.place(relx=0.5,rely=0.25)
t3.place(relx=0.5,rely=0.3)
t4.place(relx=0.5,rely=0.35)
t5.place(relx=0.5,rely=0.4)
t6.place(relx=0.5,rely=0.45)
t7.place(relx=0.5,rely=0.5)
t8.place(relx=0.5,rely=0.55)
t9.place(relx=0.5,rely=0.6)
root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-30-5eda2f7978c5>", line 2, in action1
#     data=[[int(t2.get()),int(t3.get()),int(t4.get()) ,
# ValueError: invalid literal for int() with base 10: '0.2'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-31-b10e291a053c>", line 2, in action2
#     data=[[int(t2.get()),int(t3.get()),int(t4.get()) ,
# ValueError: invalid literal for int() with base 10: '0.2'
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-31-b10e291a053c>", line 2, in action2
# ...
